# %%
import pandas as pd

import numpy as np

from sklearn import datasets

from sklearn.model_selection import GridSearchCV

from sklearn.svm import SVC

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import KFold

# %%
import json
import gc
import random
i = 0
reviews_lst_good= []
reviews_lst_bad = []
count_good_comments = 0
count_bad_comments = 0


with open('G:\\Мой диск\\Work\\Experiment\\Books_5.json', 'r') as f: # указать свой путь  /Volumes/GoogleDrive/Мой диск/Work/Experiment/Books_5.json
        for line in f:
            if json.loads(line)['overall'] > 3:
                  count_good_comments += 1
            elif json.loads(line)['overall'] < 3:
                  count_bad_comments += 1
            
print (count_good_comments)
print (count_bad_comments)
# Out:
# 7203909
# 738943

# %%
size_of_df = min (count_good_comments, count_bad_comments)
print (size_of_df)

with open('G:\\Мой диск\\Work\\Experiment\\Books_5.json', 'r') as f: #/Volumes/GoogleDrive/Мой диск/Work/Experiment/Books_5.json
        for line in f:
            if json.loads(line)['overall'] > 3 and len(reviews_lst_good)<size_of_df:
                reviews_lst_good.append (json.loads(line))
            
            elif json.loads(line)['overall'] < 3 and len(reviews_lst_bad)<size_of_df:
                reviews_lst_bad.append (json.loads(line))

            if len(reviews_lst_good) + len (reviews_lst_bad) == 10000000:
                break

random.shuffle(reviews_lst_good)
random.shuffle(reviews_lst_bad)
# Out:
# 738943

# %%
print (len(reviews_lst_good))
print (len(reviews_lst_bad))
# Out:
# 738944
# 738943

# %%
reviewerID_lst = []
reviewerName_lst = []
reviewText_lst = []
overall_lst = []
summary_lst = []

# reviews_lst [0]['overall']<5 #['asin']for 

for i in reviews_lst_good:
    reviewerID_lst.append (i['reviewerID'])
    reviewText_lst.append (i['reviewText'])
    overall_lst.append (i['overall'])
    summary_lst.append (i['summary'])
    
for i in reviews_lst_bad:
    reviewerID_lst.append (i['reviewerID'])
    reviewText_lst.append (i['reviewText'])
    overall_lst.append (i['overall'])
    summary_lst.append (i['summary'])
    
df = pd.DataFrame ()

df['reviewerID'] = reviewerID_lst
# df['reviewerName'] = reviewerName_lst
df['reviewText'] = reviewText_lst
df['overall'] = overall_lst
df['summary'] = summary_lst

# %%
df ['mark'] = -1
df.loc[df['overall'] > 3,'mark'] = 1

print (len(df[df['mark'] > 0]))
print (len(df[df['mark'] < 0]))
# Out:
# 738944
# 738943

# %%
df[(df['mark'] != 0)&(df['mark'] != 1)]
# Out:
#              reviewerID                                         reviewText  \
# 738944    AEQCJJ6ZAHEFV  I thought, by the title, it was funny, but it ...
# 738945    A9TMSN13Q32V1  I don't know quite what to say about this book...
# 738946   A16QQ78I8J29PA  I normally love T. Jefferson Parker's books, b...
# 738947   A1XO5MWVQ63HVK  The beginning of this book was very difficult ...
# 738948   A2A7U6IERQQNN4  This was a true rip-off! The book is only 5 in...
# 738949    ADUH7FZMW185H  I only read the story of the concubine in Judg...
# 738950    AT6B6Y8L9Z3AP  A little too cutesy and not really a very good...
# 738951   A1TB30UL8TM354  I was open to the Bigfoot concept and open to ...
# 738952   A3U41P3MHAEXYU  Lady Catherine and Baron Borgeault have been m...
# 1477877   A9JHHS9NG376G  --only made it to page 30.  I did NOT care wha...
# 1477878  A3R95WCDPQNDUC  A husband and wife were just convicted today o...
# 1477879  A2IU2BSVWQLKJ7  Satan is just a metaphor. Human beings are mad...
# 1477880  A2E30DLO4M53W9  This is one of two books that I have not finis...
# 1477881   AI280927NB86K  Neatbilst Jude Deveraux standartiem. T&#257; j...
# 1477882  A2SW5ZEGJQGBB2  The book has alot of good baby photos, but the...
# 1477883  A3L00A15HDNQGK  Be warned all ye who read these reviews: This ...
# 1477884  A2NIEKJ7HZVXGT  This is not a novel for self-respecting Jane A...
# 1477885  A367CSHRY9PHYI  I always feel terrible giving a book such a lo...
# 1477886   A6PBZ5PD7ROB6  A fantasy story? How terrific! Only this falls...
#
#          overall                                            summary  mark
# 738944       2.0                                              Wordy    -1
# 738945       1.0                   Be Fearful of reading this book!    -1
# 738946       2.0                                 Couldn't Finish It    -1
# 738947       2.0                           Lacking something.......    -1
# 738948       2.0                                    Any Pride Left?    -1
# 738949       1.0                  Misogynistic romanticized garbage    -1
# 738950       1.0                        Bad stand up comedy routine    -1
# 738951       2.0                                Bigfoot:I Not Good!    -1
# 738952       2.0                                 THIS IS A ROMANCE?    -1
# 738953       1.0                             Distasteful and boring    -1
# 738954       2.0  Safe, even predictable book  Being generous wi...    -1
# 738955       2.0                           Just didn't do it for me    -1
# 738956       2.0  Poor book to use as a representation of 'norma...    -1
# 738957       2.0  I thought this was a book about the "First Gen...    -1
# 738958       2.0                                     It's a Klunker    -1
# 738959       2.0                             "It just doesn't sing"    -1
# 738960       1.0                        The Four Obvious Statements    -1
# 738961       2.0                                             Review    -1
# 738962       1.0                                Again, disappointed    -1
# 738963       2.0                          I did not finish the book    -1
# 738964       1.0             Not the Betty Crocker of days gone by!    -1
# 738965       2.0                                       An okay book    -1
# 738966       1.0                              This Book is Unusable    -1
# 738967       2.0                                        not so good    -1
# 738968       2.0  Bo-oring!!! If you must read, get it from the ...    -1
# 738969       1.0                     Narcopolis: Not worth my trip.    -1
# 738970       1.0                                   The Chosen Snore    -1
# 738971       1.0                                     Wrong content!    -1
# 738972       2.0                             Only for Hardcore fans    -1
# 738973       2.0                           That terrible in-between    -1
# ...          ...                                                ...   ...
# 1477857      2.0                      The Lion was a little limp...    -1
# 1477858      2.0           Read my review on Book #6 of this series    -1
# 1477859      1.0  Confusing, Disjointed Writing; Don't waste you...    -1
# 1477860      1.0                      "I could'nt finish this book"    -1
# 1477861      1.0                                not what I expected    -1
# 1477862      2.0                                  The Woman's Bible    -1
# 1477863      2.0                          Bored Stiff, Pun Intended    -1
# 1477864      1.0                         There are far worse losses    -1
# 1477865      1.0  smells like dmeocrat scifi remember FDR caused...    -1
# 1477866      2.0         Not sure how many starts to give this book    -1
# 1477867      2.0                                        Pretty bad!    -1
# 1477868      2.0                    Annoying and overly complicated    -1
# 1477869      2.0                           Not my kind of "romance"    -1
# 1477870      2.0                                    Dumb and dummer    -1
# 1477871      2.0             Misdirecting the reader is problematic    -1
# 1477872      1.0                                      Waste of Time    -1
# 1477873      2.0                                     Mixed messages    -1
# 1477874      1.0                           badly, so badly, written    -1
# 1477875      1.0                                               poor    -1
# 1477876      2.0               Bad Example of a Great Author's Work    -1
# 1477877      2.0                                       Thumbs Down!    -1
# 1477878      1.0                                       Just sick...    -1
# 1477879      2.0             ANY WISEMAN OR MYSTIC WILL TELL YOU...    -1
# 1477880      1.0            I did not finish it - I was that bad!!!    -1
# 1477881      2.0                                         Neizdevies    -1
# 1477882      2.0                                     no cute babies    -1
# 1477883      1.0  Zero Star Book:  Jordan has killed a Great Ser...    -1
# 1477884      2.0                    No sensibility and little sense    -1
# 1477885      2.0                    Extremely weak female character    -1
# 1477886      2.0  Awful, it was boring and focuses too much on f...    -1
#
# [738943 rows x 5 columns]

# %%
reviews_train = list(df[df['overall'] > 3]['reviewText'][:-10000]) + list(df[df['overall'] < 3]['reviewText'][:-10000])
reviews_test = list(df[df['overall'] > 3]['reviewText'][-10000:]) + list(df[df['overall'] < 3]['reviewText'][-10000:])

# %%
import re
from nltk.corpus import stopwords 

REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

def preprocess_reviews(reviews):
    reviews = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews]
    reviews = [REPLACE_WITH_SPACE.sub(" ", line) for line in reviews]
    
    return reviews

reviews_train_clean = preprocess_reviews(reviews_train)
reviews_test_clean = preprocess_reviews(reviews_test)

# %%
from sklearn import datasets

from sklearn.model_selection import GridSearchCV

from sklearn.svm import SVC

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import KFold

from sklearn.model_selection import train_test_split

# %%
y = list(df[df['overall'] > 3]['mark'][:-10000]) + list(df[df['overall'] < 3]['mark'][:-10000])

X = reviews_train_clean

X_train, X_val, y_train, y_val = train_test_split(
    X, y, train_size = 0.75
)


vectorizer = TfidfVectorizer() # создали генератор признаков 

vectorizer.fit_transform(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# <1457887x1744343 sparse matrix of type '<class 'numpy.float64'>'
# 	with 142154424 stored elements in Compressed Sparse Row format>

# %%
grid = {'C': np.power(10.0, np.arange(-5, 6))}

cv = KFold(5, shuffle=True, random_state=241) # делим на 5 блоков

model = SVC(kernel='linear', random_state=241) # устанавливаем линейной ядро у SVM

gs = GridSearchCV(model, grid, scoring='accuracy', cv=cv) # показываем, чтобы использовал модель нашу 
# + искал параметр C сам из диапозона, метод для валивации KFold

gs.fit(vectorizer.transform(X), y)



C = gs.best_params_.get('C') # достаём оттуда только C

# %%
# 4. Обучите SVM по всей выборке с оптимальным параметром C, найденным на предыдущем шаге.



model = SVC(kernel='linear', random_state=241, C=C)

model.fit(vectorizer.transform(X), y)

# %%
# 5. Найдите 10 слов с наибольшим по модулю весом. Они являются ответом на это задание. Укажите их через запятую или

# пробел, в нижнем регистре, в лексикографическом порядке.



words = vectorizer.get_feature_names()

coef = pd.DataFrame(model.coef_.data, model.coef_.indices)

top_words = coef[0].map(lambda w: abs(w)).sort_values(ascending=False).head(10).index.map(lambda i: words[i])

top_words.sort_values ()

# top_words

# %%
top_words
